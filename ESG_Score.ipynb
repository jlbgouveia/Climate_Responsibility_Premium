# %% [markdown]
# # ESG Scores calculation

# %% [markdown]
# In this file I'll be calculating the ESG scores for the firms. The methodology is similar to the one applied by Refinitiv, however I exclude variables that are relative to the firm being, at the given period, carbon-intensive

# %%
import pandas as pd
import numpy as np

# %%
_2016 = pd.read_excel("./ESG_Calculations.xlsx", sheet_name = "2016")
_2017 = pd.read_excel("./ESG_Calculations.xlsx", sheet_name = "2017")
_2018 = pd.read_excel("./ESG_Calculations.xlsx", sheet_name = "2018")
_2018_2 = pd.read_excel("./ESG_Calculations.xlsx", sheet_name = "2018_2")
rules = pd.read_excel("./ESG_Calculations.xlsx", sheet_name = "Rules")

# %%
_2016.head()
# Out:
#      Firm Emission Reduction Processes/Policy Emissions Reduction  \
# 0  544294                                                  N
# 1  923587                                                  N
# 2  938972                                                  N
# 3  916328                                                  Y
# 4  87851X                                                  Y
#
#   Emission Reduction Objectives/Targets Emissions Reduction  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  Y
# 4                                                  Y
#
#   Biodiversity Impact Reduction NOx and SOx Emissions Reduction Initiatives  \
# 0                             N                                           N
# 1                             N                                           N
# 2                             N                                           N
# 3                             N                                           N
# 4                             N                                           N
#
#   e-Waste Reduction Initiatives Emissions Trading Environmental Partnerships  \
# 0                             N                 N                          N
# 1                             N                 N                          N
# 2                             N                 N                          N
# 3                             Y                 N                          Y
# 4                             N                 N                          Y
#
#    ISO 14000 or EMS Certified Percent Environmental Restoration Initiatives  \
# 0                                 NaN                                     N
# 1                                 NaN                                     N
# 2                                 NaN                                     N
# 3                                 NaN                                     N
# 4                                 NaN                                     N
#
#                         ...                        \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#   Resource Efficiency Objectives/Targets Water Efficiency  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  Y
# 4                                                  Y
#
#   Resource Efficiency Objectives/Targets Energy Efficiency  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  Y
# 4                                                  Y
#
#    Materials Sourcing Environmental Criteria  \
# 0                                          N
# 1                                          N
# 2                                          N
# 3                                          Y
# 4                                          Y
#
#    Toxic Substances Reduction Initiatives Green Buildings Water Recycled  \
# 0                                       N               N            NaN
# 1                                       N               N            NaN
# 2                                       N               N            NaN
# 3                                       N               Y            NaN
# 4                                       Y               N            NaN
#
#   Environmental Supply Chain Selection Management  \
# 0                                               N
# 1                                               N
# 2                                               N
# 3                                               Y
# 4                                               Y
#
#    Environmental Supply Chain Partnership Termination  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#    Environmental Supply Chain Monitoring  \
# 0                                    NaN
# 1                                    NaN
# 2                                      Y
# 3                                      Y
# 4                                      Y
#
#   Value - Resource Reduction/Renewable Energy Use
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                         0.00052
# 4                                             NaN
#
# [5 rows x 35 columns]

# %%
rules.head()
# Out:
#       DS_Code                                              Title Units  \
# 0  ENERDP0051  Emission Reduction Processes/Policy Emissions ...   Y/N
# 1  ENERDP0161  Emission Reduction Objectives/Targets Emission...   Y/N
# 2   ENERDP019                      Biodiversity Impact Reduction   Y/N
# 3   ENERDP033        NOx and SOx Emissions Reduction Initiatives   Y/N
# 4   ENERDP063                      e-Waste Reduction Initiatives   Y/N
#
#    Polarity              Syntax
# 0  Positive  Emission Reduction
# 1  Positive  Emission Reduction
# 2  Positive  Emission Reduction
# 3  Positive  Emission Reduction
# 4  Positive  Emission Reduction

# %%
#Now let's create one dataframe with the scores

scores = pd.DataFrame(columns = _2016.columns, index = _2016.index)
scores["Firm"] = _2016["Firm"]

# %%
scores.head()
# Out:
#      Firm Emission Reduction Processes/Policy Emissions Reduction  \
# 0  544294                                                NaN
# 1  923587                                                NaN
# 2  938972                                                NaN
# 3  916328                                                NaN
# 4  87851X                                                NaN
#
#   Emission Reduction Objectives/Targets Emissions Reduction  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Biodiversity Impact Reduction NOx and SOx Emissions Reduction Initiatives  \
# 0                           NaN                                         NaN
# 1                           NaN                                         NaN
# 2                           NaN                                         NaN
# 3                           NaN                                         NaN
# 4                           NaN                                         NaN
#
#   e-Waste Reduction Initiatives Emissions Trading Environmental Partnerships  \
# 0                           NaN               NaN                        NaN
# 1                           NaN               NaN                        NaN
# 2                           NaN               NaN                        NaN
# 3                           NaN               NaN                        NaN
# 4                           NaN               NaN                        NaN
#
#   ISO 14000 or EMS Certified Percent Environmental Restoration Initiatives  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
#
#                         ...                        \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#   Resource Efficiency Objectives/Targets Water Efficiency  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Resource Efficiency Objectives/Targets Energy Efficiency  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Materials Sourcing Environmental Criteria  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Toxic Substances Reduction Initiatives Green Buildings Water Recycled  \
# 0                                    NaN             NaN            NaN
# 1                                    NaN             NaN            NaN
# 2                                    NaN             NaN            NaN
# 3                                    NaN             NaN            NaN
# 4                                    NaN             NaN            NaN
#
#   Environmental Supply Chain Selection Management  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Environmental Supply Chain Partnership Termination  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Environmental Supply Chain Monitoring  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Value - Resource Reduction/Renewable Energy Use
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
# [5 rows x 35 columns]

# %%
dummies = rules.loc[rules["Units"] == "Y/N"]
values_positive = rules.loc[rules["Polarity"] == "Positive"].loc[rules["Units"]!="Y/N"]
values_negative = rules.loc[rules["Polarity"] == "Negative"].loc[rules["Units"]!="Y/N"]

# %%
#Scores for dummies: Easiest ones to compute

for score in dummies["Title"]:
    #Score for Yes
    Y = (len(_2016[score].loc[_2016[score]== "N"]) + 0.5*len(_2016[score].loc[_2016[score]== "Y"]))/(len(_2016[score]))
    #Score for No
    N = 0.5*len(_2016[score].loc[_2016[score]=="N"])/len(_2016[score])
    NA = 0
    
    scores[score] = np.where(_2016[score] == "Y", Y, N) #inserting values
    
    #replacing with zero in case there are Nans in the series
    if len(_2016.loc[_2016[score].isna()]) > 0:
        scores[score] = np.where(_2016[score].isna(), 0, scores[score])

# %%
#Scores positive for values :

for score in values_positive["Title"]:
    score_list = list()
    _2016.set_index("Firm", inplace = True, drop = True) #Setting index to firms
    
    for firm in _2016.index:
        score_list.append((len(_2016[score].dropna().loc[_2016[score] < _2016.loc[firm,score]]) + 0.5*len(_2016[score].dropna().loc[_2016[score] < _2016.loc[firm,score]]))/len(_2016[score]))
         
    #Removing index
    _2016.reset_index("Firm", inplace = True)
    #insert list in DataFrame scores:
    scores[score] = score_list

# %%
scores.loc[:,values_positive["Title"]].describe()
# Out:
#        ISO 14000 or EMS Certified Percent  \
# count                         2102.000000
# mean                             0.001544
# std                              0.007326
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              0.041389
#
#        Value - Emission Reduction/Waste Recycling Ratio  \
# count                                       2102.000000
# mean                                           0.007428
# std                                            0.026126
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            0.149857
#
#        Value - Product Innovation/Environmental R&D Expenditures  \
# count                                        2102.000000
# mean                                            0.000005
# std                                             0.000115
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             0.003568
#
#        Value - Product Innovation/Renewable Energy Supply  Water Recycled  \
# count                                        2102.000000      2102.000000
# mean                                            0.000022         0.000773
# std                                             0.001027         0.004924
# min                                             0.000000         0.000000
# 25%                                             0.000000         0.000000
# 50%                                             0.000000         0.000000
# 75%                                             0.000000         0.000000
# max                                             0.047098         0.047812
#
#        Value - Resource Reduction/Renewable Energy Use
# count                                      2102.000000
# mean                                          0.001205
# std                                           0.006839
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           0.059943

# %%
values_negative
# Out:
#       DS_Code                              Title  \
# 11  ENERDP103  Self-Reported Environmental Fines
#
#                                               Units  Polarity  \
# 11  Number (Currency = Local Reporting Currency)/NA  Negative
#
#                 Syntax
# 11  Emission Reduction

# %%
#Score for the only negative value: "Self-Reported Environmental Fines"

score = "Self-Reported Environmental Fines"
score_list = list()
_2016.set_index("Firm", inplace = True, drop = True) #Setting index to firms

for firm in _2016.index:
    score_list.append(-(len(_2016[score].dropna().loc[_2016[score] < _2016.loc[firm,score]]) + 0.5*len(_2016[score].dropna().loc[_2016[score] < _2016.loc[firm,score]]))/len(_2016[score]))

#Removing index
_2016.reset_index("Firm", inplace = True)
#insert list in DataFrame scores:
scores[score] = score_list

# %%
scores[score].describe()
# Out:
# count    2102.000000
# mean       -0.001819
# std         0.011068
# min        -0.087060
# 25%        -0.000000
# 50%        -0.000000
# 75%        -0.000000
# max        -0.000000
# Name: Self-Reported Environmental Fines, dtype: float64

# %% [markdown]
# # Repeat The Process, for 2017: Paris

# %%
scores17 = pd.DataFrame(columns = _2017.columns, index = _2017.index)
scores17["Firm"] = _2017["Firm"]

#Scores for dummies: Easiest ones to be fair

for score in dummies["Title"]:
    #Score for Yes
    Y = (len(_2017[score].loc[_2017[score]== "N"]) + 0.5*len(_2017[score].loc[_2017[score]== "Y"]))/(len(_2017[score]))
    #Score for No
    N = 0.5*len(_2017[score].loc[_2017[score]=="N"])/len(_2017[score])
    NA = 0
    
    scores17[score] = np.where(_2017[score] == "Y", Y, N) #inserting values
    
    #replacing with zero in case there are Nans in the series
    if len(_2017.loc[_2017[score].isna()]) > 0:
        scores17[score] = np.where(_2017[score].isna(), 0, scores17[score])
        
#Scores positive for values :

for score in values_positive["Title"]:
    score_list = list()
    _2017.set_index("Firm", inplace = True, drop = True) #Setting index to firms
    
    for firm in _2017.index:
        score_list.append((len(_2017[score].dropna().loc[_2017[score] < _2017.loc[firm,score]]) + 0.5*len(_2017[score].dropna().loc[_2017[score] < _2017.loc[firm,score]]))/len(_2017[score]))
         
    #Removing index
    _2017.reset_index("Firm", inplace = True)
    #insert list in DataFrame scores:
    scores17[score] = score_list

# %% [markdown]
# # Repeat The Process, for 2018: To be used on Long-Term Analysis

# %%
scores18 = pd.DataFrame(columns = _2018.columns, index = _2018.index)
scores18["Firm"] = _2018["Firm"]

#Scores for dummies: Easiest ones to be fair

for score in dummies["Title"]:
    #Score for Yes
    Y = (len(_2018[score].loc[_2018[score]== "N"]) + 0.5*len(_2018[score].loc[_2018[score]== "Y"]))/(len(_2018[score]))
    #Score for No
    N = 0.5*len(_2018[score].loc[_2018[score]=="N"])/len(_2018[score])
    NA = 0
    
    scores18[score] = np.where(_2018[score] == "Y", Y, N) #inserting values
    
    #replacing with zero in case there are Nans in the series
    if len(_2018.loc[_2018[score].isna()]) > 0:
        scores18[score] = np.where(_2018[score].isna(), 0, scores18[score])
        
#Scores positive for values :

for score in values_positive["Title"]:
    score_list = list()
    _2018.set_index("Firm", inplace = True, drop = True) #Setting index to firms
    
    for firm in _2018.index:
        score_list.append((len(_2018[score].dropna().loc[_2018[score] < _2018.loc[firm,score]]) + 0.5*len(_2018[score].dropna().loc[_2018[score] < _2018.loc[firm,score]]))/len(_2018[score]))
         
    #Removing index
    _2018.reset_index("Firm", inplace = True)
    #insert list in DataFrame scores:
    scores18[score] = score_list

# %% [markdown]
# # Repeat The Process, for 2018_2: To be used on Long-Term Analysis

# %%
scores18_2 = pd.DataFrame(columns = _2018_2.columns, index = _2018_2.index)
scores18_2["Firm"] = _2018_2["Firm"]

#Scores for dummies: Easiest ones to be fair

for score in dummies["Title"]:
    #Score for Yes
    Y = (len(_2018_2[score].loc[_2018_2[score]== "N"]) + 0.5*len(_2018_2[score].loc[_2018_2[score]== "Y"]))/(len(_2018_2[score]))
    #Score for No
    N = 0.5*len(_2018_2[score].loc[_2018_2[score]=="N"])/len(_2018_2[score])
    NA = 0
    
    scores18_2[score] = np.where(_2018_2[score] == "Y", Y, N) #inserting values
    
    #replacing with zero in case there are Nans in the series
    if len(_2018_2.loc[_2018_2[score].isna()]) > 0:
        scores18_2[score] = np.where(_2018_2[score].isna(), 0, scores18_2[score])
        
#Scores positive for values :

for score in values_positive["Title"]:
    score_list = list()
    _2018_2.set_index("Firm", inplace = True, drop = True) #Setting index to firms
    
    for firm in _2018_2.index:
        score_list.append((len(_2018_2[score].dropna().loc[_2018_2[score] < _2018_2.loc[firm,score]]) + 0.5*len(_2018_2[score].dropna().loc[_2018_2[score] < _2018_2.loc[firm,score]]))/len(_2018_2[score]))
         
    #Removing index
    _2018_2.reset_index("Firm", inplace = True)
    #insert list in DataFrame scores:
    scores18_2[score] = score_list

# %% [markdown]
# # Computing final Env_Scores

# %% [markdown]
# Now that we have the scores per variable, let's compute the full environmental score:
# Each individual category score gets same weight
#
# Env_Score1 --> score considering all the variables
#
# Env_Score1d --> score considering just the dummies
#
# Env_Score2 --> Not computed in this document, but is the original score
#
# And finally all these scores for Paris:
#
# Env_Score1P;  Env_Score1dP;  EnvScore2P

# %%
#Env_Score1:
scores["Env_Score1"] = scores.iloc[:,1:].sum(axis=1)/(len(scores.columns)-1)

#Env_Score1d:
scores["Env_Score1d"] = scores.loc[:,dummies["Title"]].sum(axis=1)/(len(dummies)-1)

#Env_Score1P:
scores17["Env_Score1P"] = scores17.iloc[:,1:].sum(axis=1)/(len(scores.columns)-1)

#Env_ScoredP:
scores17["Env_Score1dP"] = scores17.loc[:,dummies["Title"]].sum(axis=1)/(len(dummies)-1)

#Env_Score1P:
scores18["Env_Score1_18"] = scores18.iloc[:,1:].sum(axis=1)/(len(scores.columns)-1)

#Env_ScoredP:
scores18["Env_Score1d_18"] = scores18.loc[:,dummies["Title"]].sum(axis=1)/(len(dummies)-1)

#Env_Score1P:
scores18_2["Env_Score1_18"] = scores18_2.iloc[:,1:].sum(axis=1)/(len(scores.columns)-1)

#Env_ScoredP:
scores18_2["Env_Score1d_18"] = scores18_2.loc[:,dummies["Title"]].sum(axis=1)/(len(dummies)-1)

# %%
scores.describe()
# Out:
#        Emission Reduction Processes/Policy Emissions Reduction  \
# count                                        2102.000000
# mean                                            0.500000
# std                                             0.224371
# min                                             0.360371
# 25%                                             0.360371
# 50%                                             0.360371
# 75%                                             0.860371
# max                                             0.860371
#
#        Emission Reduction Objectives/Targets Emissions Reduction  \
# count                                        2102.000000
# mean                                            0.500000
# std                                             0.178040
# min                                             0.425547
# 25%                                             0.425547
# 50%                                             0.425547
# 75%                                             0.425547
# max                                             0.925547
#
#        Biodiversity Impact Reduction  \
# count                    2102.000000
# mean                        0.500000
# std                         0.129925
# min                         0.463606
# 25%                         0.463606
# 50%                         0.463606
# 75%                         0.463606
# max                         0.963606
#
#        NOx and SOx Emissions Reduction Initiatives  \
# count                                  2102.000000
# mean                                      0.500000
# std                                       0.091568
# min                                       0.482636
# 25%                                       0.482636
# 50%                                       0.482636
# 75%                                       0.482636
# max                                       0.982636
#
#        e-Waste Reduction Initiatives  Emissions Trading  \
# count                    2102.000000        2102.000000
# mean                        0.500000           0.500000
# std                         0.168385           0.087217
# min                         0.434824           0.484301
# 25%                         0.434824           0.484301
# 50%                         0.434824           0.484301
# 75%                         0.434824           0.484301
# max                         0.934824           0.984301
#
#        Environmental Partnerships  ISO 14000 or EMS Certified Percent  \
# count                 2102.000000                         2102.000000
# mean                     0.500000                            0.001544
# std                      0.203631                            0.007326
# min                      0.395100                            0.000000
# 25%                      0.395100                            0.000000
# 50%                      0.395100                            0.000000
# 75%                      0.395100                            0.000000
# max                      0.895100                            0.041389
#
#        Environmental Restoration Initiatives  \
# count                            2102.000000
# mean                                0.500000
# std                                 0.139591
# min                                 0.457422
# 25%                                 0.457422
# 50%                                 0.457422
# 75%                                 0.457422
# max                                 0.957422
#
#        Staff Transport Impact Reduction Initiatives     ...       \
# count                                   2102.000000     ...
# mean                                       0.500000     ...
# std                                        0.161894     ...
# min                                        0.440533     ...
# 25%                                        0.440533     ...
# 50%                                        0.440533     ...
# 75%                                        0.440533     ...
# max                                        0.940533     ...
#
#        Materials Sourcing Environmental Criteria  \
# count                                2102.000000
# mean                                    0.500000
# std                                     0.181716
# min                                     0.421741
# 25%                                     0.421741
# 50%                                     0.421741
# 75%                                     0.421741
# max                                     0.921741
#
#        Toxic Substances Reduction Initiatives  Green Buildings  \
# count                             2102.000000      2102.000000
# mean                                 0.500000         0.500000
# std                                  0.130315         0.199438
# min                                  0.463368         0.400809
# 25%                                  0.463368         0.400809
# 50%                                  0.463368         0.400809
# 75%                                  0.463368         0.400809
# max                                  0.963368         0.900809
#
#        Water Recycled  Environmental Supply Chain Selection Management  \
# count     2102.000000                                      2102.000000
# mean         0.000773                                         0.500000
# std          0.004924                                         0.218646
# min          0.000000                                         0.371313
# 25%          0.000000                                         0.371313
# 50%          0.000000                                         0.371313
# 75%          0.000000                                         0.871313
# max          0.047812                                         0.871313
#
#        Environmental Supply Chain Partnership Termination  \
# count                                         2102.00000
# mean                                             0.50000
# std                                              0.15612
# min                                              0.44529
# 25%                                              0.44529
# 50%                                              0.44529
# 75%                                              0.44529
# max                                              0.94529
#
#        Environmental Supply Chain Monitoring  \
# count                            2102.000000
# mean                                0.011229
# std                                 0.026800
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 0.075167
#
#        Value - Resource Reduction/Renewable Energy Use   Env_Score1  \
# count                                      2102.000000  2102.000000
# mean                                          0.001205     0.382953
# std                                           0.006839     0.085674
# min                                           0.000000     0.320325
# 25%                                           0.000000     0.320325
# 50%                                           0.000000     0.335031
# 75%                                           0.000000     0.423266
# max                                           0.059943     0.697613
#
#        Env_Score1d
# count  2102.000000
# mean      0.500432
# std       0.111434
# min       0.418887
# 25%       0.418887
# 50%       0.438118
# 75%       0.553502
# max       0.902547
#
# [8 rows x 36 columns]

# %%
#Exporting Final Scores:
final = scores.loc[:,["Firm","Env_Score1","Env_Score1d"]]
finalp = scores17.loc[:,["Firm","Env_Score1P","Env_Score1dP"]]
final18 = scores18.loc[:,["Firm","Env_Score1_18","Env_Score1d_18"]]
final18_2 = scores18_2.loc[:,["Firm","Env_Score1_18","Env_Score1d_18"]]

# %%
""""
with pd.ExcelWriter("./Env_Scores.xlsx") as writer:
    final.to_excel(writer, sheet_name='2016')
    finalp.to_excel(writer, sheet_name='2017')
    final18.to_excel(writer, sheet_name='2018')
    final18_2.to_excel(writer, sheet_name='2018_2')
